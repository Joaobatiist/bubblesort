# %% [markdown]
# <a href="https://colab.research.google.com/github/Joaobatiist/bubblesort/blob/main/Ol%C3%A1%2C_este_%C3%A9_o_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nova seção

# %%
import pandas as pd
tabela = pd.read_excel("/content/sample_data/Vendas.xlsx")
display(tabela)
# Out:
#          Data            ID Loja           Produto  Quantidade  \
# 0  2019-12-01  Shopping da Bahia   Bermuda Estampa           1
# 1  2019-12-01  Shopping Paralela    Bermuda Xadrez           1
# 2  2019-12-01     Norte Shopping           Bermuda           2
# 3  2019-12-01  Shopping da Bahia  Bermuda Listrado           3
# 4  2019-12-01  Shopping da Bahia     Bermuda Linho           3
# 5  2019-12-03  Shopping da Bahia    Bermuda Xadrez           1
# 6  2019-12-03    Parque shopping  Bermuda Listrado           1
# 7  2019-12-03    Parque shopping    Bermuda Xadrez           3
# 8  2019-12-03    Parque shopping   Bermuda Estampa           1
# 9  2019-12-04      Shopping lapa    Bermuda Xadrez           4
# 10 2019-12-04  Shopping Paralela           Bermuda           1
# 11 2019-12-04    Parque shopping   Bermuda Estampa           2
# 12 2019-12-04  Shopping da Bahia           Bermuda           4
# 13 2019-12-05  Shopping da Bahia      Bermuda Liso          55
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_4.groupby('ID Loja').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_5.groupby('Produto').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Panorama total sobre a asua base de dados

# %%
faturamento_total = tabela["Valor Final"].sum()
print(faturamento_total)
# Out:
# 55895

# %% [markdown]
#   Analise top -> Down

# %% [markdown]
# # Nova seção

# %%
faturamento_por_loja = tabela[["ID Loja", "Valor Final"]].groupby("ID Loja").sum()
display(faturamento_por_loja)
# Out:
#                    Valor Final
# ID Loja
# Norte Shopping            4322
# Parque shopping           4386
# Shopping Paralela         2473
# Shopping da Bahia        41720
# Shopping lapa             2994

# %% [markdown]
# Detalhe de Vendas

# %%
faturamento_do_produto = tabela[["ID Loja","Produto", "Valor Final"]].groupby(["ID Loja", "Produto"]).sum()
display(faturamento_do_produto)
# Out:
#                                     Valor Final
# ID Loja           Produto
# Norte Shopping    Bermuda                  1350
#                   Bermuda Estampa           845
#                   Bermuda Linho             390
#                   Bermuda Listrado          652
#                   Bermuda Xadrez           1085
# Parque shopping   Bermuda                   750
#                   Bermuda Estampa          1183
#                   Bermuda Linho             195
#                   Bermuda Listrado         1793
#                   Bermuda Xadrez            465
# Shopping Paralela Bermuda                   150
#                   Bermuda Estampa           338
#                   Bermuda Linho            1365
#                   Bermuda Xadrez            620
# Shopping da Bahia Bermuda                  1200
#                   Bermuda Estampa           845
#                   Bermuda Linho            1170
#                   Bermuda Liso            36581
# ...
